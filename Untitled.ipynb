# %%
import pandas as pd 
import os
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine

csv_to_convert = os.path.join("sample.csv") 

content_df = pd.read_csv(csv_to_convert).reset_index()
icap = len(content_df)
print(icap)

titles = []
posts = []
dates = []
times = []
labels = []
channels = []

i = 0
print("first check")

while i < icap:
    print(f"Start no. {i}")
    if content_df.iloc[i]["Auto Imported"] == "no":
        j = i+1
        k = i+2
        current_post_dict = {}
        title = content_df.iloc[i]['Title']
        post_text = content_df.iloc[i]['Content']
        pub_date = content_df.iloc[i]["Date"]
        pub_time = content_df.iloc[i]["Time"]
        all_labels = content_df.iloc[i]["Labels"].split(",")

        for label in all_labels:
            if label[:16] == "Dolby Initiative":
                primary_label = label

        post_channels = content_df.iloc[i]["Accounts"]
        print("got here")

        if (len(content_df)) >= (j):
            if content_df.iloc[j]["Title"] == title:
                new_channels = content_df.iloc[j]["Accounts"]
                print(f"Check out these new channels: {new_channels}")
                post_channels = f"{post_channels},{new_channels}"
#                 See if next cell exists, then if it is also a duplicate
                if (len(content_df)) >= k:
                    if content_df.iloc[k]["Title"] == title:
                        new_channels = content_df.iloc[k]["Accounts"]
                        post_channels = f"{post_channels},{new_channels}"
                        i += 3
                    else:
#                         current_post_dict["title"] = title
#                         current_post_dict["post content/description"] = post_text
#                         current_post_dict["publish date"] = pub_date
#                         current_post_dict["publish time"] = pub_time
#                         current_post_dict["labels"] = primary_label
#                         current_post_dict["channel"] = channels
#                         current_post_df = pd.DataFrame(current_post_dict, index=[0])
#                         converted_df.append(current_post_df)
                        i += 2
                        continue

            else:
                i += 1

        titles.append(title)
        posts.append(post_text)
        dates.append(pub_date)
        times.append(pub_time)
        labels.append(primary_label)
        channels.append(post_channels)
    else:
        i = i + 1
        

        
print(channels)
# Out:
# 37
# first check
# Start no. 0
# got here
# Check out these new channels: FB: Dolby Cinema HQ:Page: Dolby Cinema (Default)
# Start no. 2
# got here
# Check out these new channels: FB: Dolby Cinema HQ:Page: Dolby Cinema (Default)
# Start no. 5
# Start no. 6
# Start no. 7
# got here
# Check out these new channels: FB: Dolby Cinema HQ:Page: Dolby Cinema (Default)
# Start no. 10
# Start no. 11
# Start no. 12
# got here
# Check out these new channels: FB: Dolby Cinema HQ:Page: Dolby Cinema (Default)
# Start no. 15
# Start no. 16
# Start no. 17
# got here
# Start no. 18
# Start no. 19
# Start no. 20
# Start no. 21
# Start no. 22
# got here
# Start no. 23
# Start no. 24
# Start no. 25
# got here
# Start no. 26
# Start no. 27
# Start no. 28
# Start no. 29
# Start no. 30
# got here
# Check out these new channels: FB: Dolby Cinema HQ:Page: Dolby Cinema (Default)
# Start no. 33
# got here
# Start no. 34
# got here
# Check out these new channels: FB: Dolby Cinema HQ:Page: Dolby Cinema (Default)
# ['TW: Dolby Cinema HQ:DolbyCinema,FB: Dolby Cinema HQ:Page: Dolby Cinema (Default),IG: Dolby Cinema HQ:dolbycinema', 'IG: Dolby Cinema HQ:dolbycinema,FB: Dolby Cinema HQ:Page: Dolby Cinema (Default),TW: Dolby Cinema HQ:DolbyCinema', 'IG: Dolby Cinema HQ:dolbycinema,FB: Dolby Cinema HQ:Page: Dolby Cinema (Default),TW: Dolby Cinema HQ:DolbyCinema', 'TW: Dolby Cinema HQ:DolbyCinema', 'TW: Dolby Cinema HQ:DolbyCinema', 'TW: Dolby Cinema HQ:DolbyCinema', 'TW: Dolby Cinema HQ:DolbyCinema,FB: Dolby Cinema HQ:Page: Dolby Cinema (Default),IG: Dolby Cinema HQ:dolbycinema', 'LI: Dolby Laboratories HQ:Company: Dolby Laboratories (Thom Brekke)', 'IG: Dolby Cinema HQ:dolbycinema,FB: Dolby Cinema HQ:Page: Dolby Cinema (Default),TW: Dolby Cinema HQ:DolbyCinema']

# %%
content_df
